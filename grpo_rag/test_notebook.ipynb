# %%
import os
import pandas as pd
import dotenv

# %%
# Out:
# '/Users/Tildi/projects/grpo_rag/grpo_rag'

# %%
data_path = "data/DataScience_QA.csv"

# %%
df = pd.read_csv(data_path)

# %%
df
# Out:
#                                               Question  \
# 0    What is the purpose of feature engineering in ...
# 1    What are some common techniques for feature en...
# 2    What is the difference between batch processin...
# 3           What is natural language processing (NLP)?
# 4                          What is sentiment analysis?
# ..                                                 ...
# 153  What is the role of rewards in reinforcement l...
# 154  What is the policy gradient in reinforcement l...
# 155  What is the advantage of deep reinforcement le...
# 156  What are some applications of reinforcement le...
# 157   What is policy search in reinforcement learning?
#
#                                                 Answer
# 0    Feature engineering involves selecting, transf...
# 1    Common techniques include one-hot encoding for...
# 2    Batch processing involves processing data in l...
# 3    Natural language processing is a field of arti...
# ...
